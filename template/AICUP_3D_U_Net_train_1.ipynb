# %% [markdown]
# 設定路徑

# %%
import os

workspace_dir = "/root/Document/ai_cup_ctseg/CardiacSegV2"
model_name = 'swinunetr'
data_name = 'chgh'
exp_name = 'exp_swin'
data_dict_file_name = 'AICUP_training.json'

# set exp dir
root_exp_dir = os.path.join(workspace_dir,'exps','exps',model_name,data_name,'tune_results')

# set data dir
root_data_dir = os.path.join(workspace_dir,'dataset',data_name)
data_dir = os.path.join(root_data_dir)
# data dict json path
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# set model, log, eval dir
model_dir = os.path.join('./', 'models')
log_dir = os.path.join('./', 'logs')
eval_dir = os.path.join('./', 'evals')
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)


# model path
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# mkdir root exp dir
os.makedirs(root_exp_dir, exist_ok=True)

# %% [markdown]
# 正式訓練

# %%
# training
# !python ../CardiacSegV2/expers/tune.py \
--tune_mode="train" \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--start_epoch=0 \
--val_every=5 \
--max_early_stop_count=2 \
--max_epoch=20  \
--data_dicts_json={data_dicts_json} \
--out_channels=4 \
--patch_size=4 \
--feature_size=24 \
--drop_rate=0.1 \
--depths 3 3 3 3 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-42 \
--a_max=423 \
--space_x=0.7 \
--space_y=0.7 \
--space_z=1.0 \
--roi_x=64 \
--roi_y=64 \
--roi_z=64 \
--optim="AdamW" \
--lr=5e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
--batch_size=1
# Out:
# 2025-10-12 02:34:54,642	INFO worker.py:1625 -- Started a local Ray instance.
# 2025-10-12 02:34:54,761	INFO packaging.py:520 -- Creating a file package for local directory '/root/Document/ai_cup_ctseg/CardiacSegV2'.
# 2025-10-12 02:34:54,799	WARNING packaging.py:394 -- File /root/Document/ai_cup_ctseg/CardiacSegV2/.git/objects/pack/pack-69949eee409e54934508cf24419a0eb87c481e44.pack is very large (17.31MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['/root/Document/ai_cup_ctseg/CardiacSegV2/.git/objects/pack/pack-69949eee409e54934508cf24419a0eb87c481e44.pack']})`
# 2025-10-12 02:34:54,902	INFO packaging.py:347 -- Pushing file package 'gcs://_ray_pkg_428460d57aad73b5.zip' (37.74MiB) to Ray cluster...
# 2025-10-12 02:34:55,249	INFO packaging.py:360 -- Successfully pushed file package 'gcs://_ray_pkg_428460d57aad73b5.zip'.
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/ray/tune/experiment/experiment.py:170: UserWarning: The `local_dir` argument of `Experiment is deprecated. Use `storage_path` or set the `TUNE_RESULT_DIR` environment variable instead.
#   warnings.warn(
# 2025-10-12 02:34:57,073	INFO tensorboardx.py:172 -- pip install "ray[tune]" to see TensorBoard files.
# 2025-10-12 02:34:57,073	WARNING callback.py:142 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2025-10-12 02:34:57 (running for 00:00:00.65)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# (func pid=14683) a_max 423.0
# (func pid=14683) a_min -42.0
# (func pid=14683) space_x 0.7
# (func pid=14683) roi_x 64
# (func pid=14683) lr 0.0005
# (func pid=14683) weight_decay 0.0005
# (func pid=14683) warmup_epochs 50
# (func pid=14683) max_epochs 20
# (func pid=14683) cuda is available
# (func pid=14683) model: swinunetr
# (func pid=14683) loss: dice ce loss
# (func pid=14683) optimzer: AdamW
# (func pid=14683) {'lr': 0.0005, 'weight_decay': 0.0005}
# (func pid=14683) load json from /root/Document/ai_cup_ctseg/CardiacSegV2/exps/data_dicts/chgh/AICUP_training.json
# (func pid=14683) train files (40): ['patient0001', 'patient0002', 'patient0003', 'patient0004', 'patient0005', 'patient0006', 'patient0007', 'patient0008', 'patient0009', 'patient0010', 'patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019', 'patient0020', 'patient0021', 'patient0022', 'patient0023', 'patient0024', 'patient0025', 'patient0026', 'patient0027', 'patient0028', 'patient0029', 'patient0030', 'patient0031', 'patient0032', 'patient0033', 'patient0034', 'patient0035', 'patient0036', 'patient0037', 'patient0038', 'patient0039', 'patient0040']
# (func pid=14683) val files (5): ['patient0041', 'patient0042', 'patient0043', 'patient0044', 'patient0045']
# (func pid=14683) test files (5): ['patient0046', 'patient0047', 'patient0048', 'patient0049', 'patient0050']
# (func pid=14683)
# (func pid=14683) load train dataset ...
# (func pid=14683) Using MONAI Cache Dataset
# (func pid=14683) /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# (func pid=14683)   warn_deprecated(argname, msg, warning_category)
# (func pid=14683) /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
# (func pid=14683)   warn_deprecated(obj, msg, warning_category)
# (func pid=14683) /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
# (func pid=14683)   warn_deprecated(argname, msg, warning_category)
# Loading dataset:   0%|          | 0/40 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-10-12 02:35:06 (running for 00:00:09.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:   2%|▎         | 1/40 [00:07<04:38,  7.15s/it]
# Loading dataset:   5%|▌         | 2/40 [00:07<02:03,  3.24s/it]
# == Status ==
# Current time: 2025-10-12 02:35:11 (running for 00:00:14.67)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:   8%|▊         | 3/40 [00:13<02:41,  4.36s/it]
# == Status ==
# Current time: 2025-10-12 02:35:16 (running for 00:00:19.68)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  10%|█         | 4/40 [00:14<01:48,  3.01s/it]
# Loading dataset:  12%|█▎        | 5/40 [00:18<01:58,  3.37s/it]
# Loading dataset:  15%|█▌        | 6/40 [00:19<01:24,  2.49s/it]
# == Status ==
# Current time: 2025-10-12 02:35:21 (running for 00:00:24.68)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#

# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  82%|████████▎ | 33/40 [01:45<00:21,  3.02s/it]
# Loading dataset:  85%|████████▌ | 34/40 [01:48<00:18,  3.05s/it]
# == Status ==
# Current time: 2025-10-12 02:36:51 (running for 00:01:54.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  88%|████████▊ | 35/40 [01:51<00:15,  3.10s/it]
# Loading dataset:  90%|█████████ | 36/40 [01:53<00:10,  2.74s/it]
# == Status ==
# Current time: 2025-10-12 02:36:56 (running for 00:01:59.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  92%|█████████▎| 37/40 [01:57<00:09,  3.24s/it]
# == Status ==
# Current time: 2025-10-12 02:37:01 (running for 00:02:04.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  95%|█████████▌| 38/40 [02:00<00:06,  3.16s/it]
# Loading dataset:  98%|█████████▊| 39/40 [02:02<00:02,  2.76s/it]
# == Status ==
# Current time: 2025-10-12 02:37:06 (running for 00:02:09.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# (func pid=14683)
# (func pid=14683) load val dataset ...
# (func pid=14683) Using MONAI Cache Dataset
# Loading dataset: 100%|██████████| 40/40 [02:07<00:00,  3.18s/it]
# Loading dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# == Status ==
# Current time: 2025-10-12 02:37:11 (running for 00:02:14.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  20%|██        | 1/5 [00:06<00:27,  6.76s/it]
# == Status ==
# Current time: 2025-10-12 02:37:16 (running for 00:02:19.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  40%|████      | 2/5 [00:07<00:09,  3.30s/it]
# == Status ==
# Current time: 2025-10-12 02:37:21 (running for 00:02:24.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset:  60%|██████    | 3/5 [00:16<00:11,  5.79s/it]
# == Status ==
# Current time: 2025-10-12 02:37:26 (running for 00:02:29.78)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# == Status ==
# Current time: 2025-10-12 02:37:31 (running for 00:02:34.78)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# Loading dataset: 100%|██████████| 5/5 [00:23<00:00,  4.65s/it]
# (func pid=14683) /tmp/ray/session_2025-10-12_02-34-52_090496_14408/runtime_resources/working_dir_files/_ray_pkg_428460d57aad73b5/runners/tuner.py:150: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# (func pid=14683)   scaler = GradScaler()
# Training (X / X Steps) (loss=X.X):   0%|          | 0/40 [00:00<?, ?it/s]
# (func pid=14683) /tmp/ray/session_2025-10-12_02-34-52_090496_14408/runtime_resources/working_dir_files/_ray_pkg_428460d57aad73b5/runners/tuner.py:73: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# (func pid=14683)   with autocast():
# (func pid=14683) /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
# (func pid=14683)   return fn(*args, **kwargs)
# (func pid=14683) /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/torch/_tensor.py:1669: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# (func pid=14683) Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:835.)
# (func pid=14683)   ret = func(*args, **kwargs)
# [Epoch 0] Training (0 Steps) (loss=2.61730):   2%|▎         | 1/40 [00:02<01:34,  2.42s/it]
# [Epoch 0] Training (1 Steps) (loss=2.31697):   5%|▌         | 2/40 [00:02<00:47,  1.25s/it]
# [Epoch 0] Training (2 Steps) (loss=2.33224):   8%|▊         | 3/40 [00:03<00:32,  1.15it/s]
# [Epoch 0] Training (3 Steps) (loss=2.17150):  10%|█         | 4/40 [00:03<00:24,  1.45it/s]
# == Status ==
# Current time: 2025-10-12 02:37:36 (running for 00:02:39.78)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#

# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# [Epoch 2] Training (98 Steps) (loss=1.13632):  48%|████▊     | 19/40 [00:08<00:08,  2.45it/s]
# [Epoch 2] Training (99 Steps) (loss=1.42380):  50%|█████     | 20/40 [00:08<00:08,  2.45it/s]
# [Epoch 2] Training (100 Steps) (loss=1.14842):  52%|█████▎    | 21/40 [00:08<00:07,  2.44it/s]
# [Epoch 2] Training (101 Steps) (loss=1.15016):  55%|█████▌    | 22/40 [00:09<00:07,  2.44it/s]
# [Epoch 2] Training (102 Steps) (loss=1.12763):  57%|█████▊    | 23/40 [00:09<00:07,  2.43it/s]
# [Epoch 2] Training (103 Steps) (loss=1.10965):  60%|██████    | 24/40 [00:10<00:06,  2.43it/s]
# [Epoch 2] Training (104 Steps) (loss=1.04679):  62%|██████▎   | 25/40 [00:10<00:06,  2.43it/s]
# [Epoch 2] Training (105 Steps) (loss=1.11490):  65%|██████▌   | 26/40 [00:11<00:05,  2.44it/s]
# [Epoch 2] Training (106 Steps) (loss=0.96950):  68%|██████▊   | 27/40 [00:11<00:05,  2.41it/s]
# [Epoch 2] Training (107 Steps) (loss=1.16306):  70%|███████   | 28/40 [00:11<00:04,  2.40it/s]
# [Epoch 2] Training (108 Steps) (loss=1.05744):  72%|███████▎  | 29/40 [00:12<00:04,  2.41it/s]
# [Epoch 2] Training (109 Steps) (loss=1.06676):  75%|███████▌  | 30/40 [00:12<00:04,  2.41it/s]
# [Epoch 2] Training (110 Steps) (loss=1.12618):  78%|███████▊  | 31/40 [00:13<00:03,  2.42it/s]
# == Status ==
# Current time: 2025-10-12 02:38:21 (running for 00:03:24.80)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+
# | Trial name       | status   | loc                  | exp                 |
# |------------------+----------+----------------------+---------------------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |
# +------------------+----------+----------------------+---------------------+
#
#
# [Epoch 2] Training (111 Steps) (loss=1.28490):  80%|████████  | 32/40 [00:13<00:03,  2.44it/s]
# [Epoch 2] Training (112 Steps) (loss=1.11015):  82%|████████▎ | 33/40 [00:13<00:02,  2.45it/s]
# [Epoch 2] Training (113 Steps) (loss=1.06310):  85%|████████▌ | 34/40 [00:14<00:02,  2.44it/s]
# [Epoch 2] Training (114 Steps) (loss=0.96809):  88%|████████▊ | 35/40 [00:14<00:02,  2.35it/s]
# [Epoch 2] Training (115 Steps) (loss=1.04353):  90%|█████████ | 36/40 [00:15<00:01,  2.36it/s]
# [Epoch 2] Training (116 Steps) (loss=1.07869):  92%|█████████▎| 37/40 [00:15<00:01,  2.40it/s]
# [Epoch 2] Training (117 Steps) (loss=1.00869):  95%|█████████▌| 38/40 [00:16<00:00,  2.42it/s]
# [Epoch 2] Training (118 Steps) (loss=0.90964):  98%|█████████▊| 39/40 [00:16<00:00,  2.43it/s]
# [Epoch 2] Training (119 Steps) (loss=1.14856): 100%|██████████| 40/40 [00:16<00:00,  2.37it/s]
# Training (X / X Steps) (loss=X.X):   0%|          | 0/40 [00:00<?, ?it/s]
# ...
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# (func pid=14683) infer time: 6.996650695800781 sec
# (func pid=14683) use post process infer
# (func pid=14683) Confusion_Vals： [[3.1209500e+05 7.3548000e+04 1.1355032e+07 9.7725000e+04]
# (func pid=14683)  [1.5210000e+03 6.7700000e+02 1.1827611e+07 8.5910000e+03]
# (func pid=14683)  [0.0000000e+00 0.0000000e+00 1.1838400e+07 0.0000000e+00]]
# (func pid=14683) infer test time aug:
# (func pid=14683) dice: [0.78468764 0.24711616        nan]
# (func pid=14683) hd95: [26.11513  23.409399       nan]
# == Status ==
# Current time: 2025-10-12 02:49:25 (running for 00:14:28.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:49:30 (running for 00:14:33.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:49:35 (running for 00:14:38.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# (func pid=14683) Confusion_Vals： [[2.0879570e+06 4.9220000e+05 7.5667336e+07 6.5784800e+05]
# (func pid=14683)  [1.0121000e+04 4.4480000e+03 7.8831744e+07 5.9029000e+04]
# (func pid=14683)  [0.0000000e+00 0.0000000e+00 7.8905344e+07 0.0000000e+00]]
# (func pid=14683) infer test original:
# (func pid=14683) dice: [0.784067  0.2417648       nan]
# (func pid=14683) hd95: [50.96077  43.749287       nan]
# (func pid=14683) sensitivity: [0.76041704 0.14636298        nan]
# (func pid=14683) specificity: [0.99353725 0.99994355 1.        ]
# (func pid=14683) infer data: {'image': '/root/Document/ai_cup_ctseg/CardiacSegV2/dataset/chgh/patient0050.nii.gz', 'label': '/root/Document/ai_cup_ctseg/CardiacSegV2/dataset/chgh/patient0050_gt.nii.gz'}
# == Status ==
# Current time: 2025-10-12 02:49:40 (running for 00:14:43.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:49:45 (running for 00:14:48.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:49:50 (running for 00:14:53.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# (func pid=14683) infer time: 9.331892013549805 sec
# (func pid=14683) use post process infer
# == Status ==
# Current time: 2025-10-12 02:49:55 (running for 00:14:58.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# (func pid=14683) Confusion_Vals： [[3.6860500e+05 7.5326000e+04 1.4004710e+07 1.5628400e+05]
# (func pid=14683)  [5.2000000e+02 2.4500000e+02 1.4594806e+07 9.3540000e+03]
# (func pid=14683)  [0.0000000e+00 0.0000000e+00 1.4604925e+07 0.0000000e+00]]
# (func pid=14683) infer test time aug:
# (func pid=14683) dice: [0.76093596 0.09775355        nan]
# (func pid=14683) hd95: [39.051247 36.523964       nan]
# == Status ==
# Current time: 2025-10-12 02:50:00 (running for 00:15:03.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:50:05 (running for 00:15:08.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# == Status ==
# Current time: 2025-10-12 02:50:10 (running for 00:15:13.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 1.0/4 CPUs, 1.0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 RUNNING)
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
# | Trial name       | status   | loc                  | exp                 |   tt_dice |   tt_hd95 |   val_bst_acc |   esc |
# |------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------|
# | main_fca78_00000 | RUNNING  | 192.168.50.120:14683 | {'exp': 'exp_swin'} |         0 |         0 |      0.614415 |     0 |
# +------------------+----------+----------------------+---------------------+-----------+-----------+---------------+-------+
#
#
# Result for main_fca78_00000:
#   date: 2025-10-12_02-50-15
#   done: false
#   hostname: LAPTOP-RRKSNUKQ
#   inf_dice: 0.38247066736221313
#   inf_hd95: 55.790771484375
#   inf_time: 10.21675157546997
#   iterations_since_restore: 5
#   node_ip: 192.168.50.120
#   pid: 14683
#   time_since_restore: 914.0664932727814
#   time_this_iter_s: 180.07620334625244
#   time_total_s: 914.0664932727814
#   timestamp: 1760208615
#   training_iteration: 5
#   trial_id: fca78_00000
#   tt_dice: 0.3794625997543335
#   tt_hd95: 29.113372802734375
#   val_bst_acc: 0.6144151091575623
#
# Trial main_fca78_00000 completed.
# == Status ==
# Current time: 2025-10-12 02:50:15 (running for 00:15:18.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/4 CPUs, 0/1 GPUs
# Result logdir: /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results/exp_swin
# Number of trials: 1/1 (1 TERMINATED)
# +------------------+------------+----------------------+---------------------+-----------+-----------+------------+------------+---------------+------------+
# | Trial name       | status     | loc                  | exp                 |   tt_dice |   tt_hd95 |   inf_dice |   inf_hd95 |   val_bst_acc |   inf_time |
# |------------------+------------+----------------------+---------------------+-----------+-----------+------------+------------+---------------+------------|
# | main_fca78_00000 | TERMINATED | 192.168.50.120:14683 | {'exp': 'exp_swin'} |  0.379463 |   29.1134 |   0.382471 |    55.7908 |      0.614415 |    10.2168 |
# +------------------+------------+----------------------+---------------------+-----------+-----------+------------+------------+---------------+------------+
#
#
# 2025-10-12 02:50:15,813	INFO tune.py:945 -- Total run time: 918.75 seconds (918.73 seconds for the tuning loop).
# (func pid=14683) Confusion_Vals： [[2.6376380e+06 4.9129600e+05 9.8542608e+07 1.0889030e+06]
# (func pid=14683)  [4.2960000e+03 1.0640000e+03 1.0269025e+08 6.4842000e+04]
# (func pid=14683)  [0.0000000e+00 0.0000000e+00 1.0276045e+08 0.0000000e+00]]
# (func pid=14683) infer test original:
# (func pid=14683) dice: [0.76949847 0.11533815        nan]
# (func pid=14683) hd95: [77.89737  69.523735       nan]
# (func pid=14683) sensitivity: [0.70779794 0.0621366         nan]
# (func pid=14683) specificity: [0.9950391 0.9999896 1.       ]
# (func pid=14683)
# (func pid=14683) eval result:
# (func pid=14683) avg tt dice: 0.3794626
# (func pid=14683) avg tt hd95: 29.113373
# (func pid=14683) avg inf dice: 0.38247067
# (func pid=14683) avg inf hd95: 55.79077
# (func pid=14683) avg inf sensitivity: 0.33071965
# (func pid=14683) avg inf specificity: 0.9981178
# (func pid=14683) avg inf time: 10.21675157546997
# (func pid=14683)      patientId  tt_diceC  tt_diceAO  tt_diceCA   tt_hd95C  tt_hd95AO  tt_hd95CA  inf_diceC  inf_diceAO  inf_diceCA  inf_hd95C  inf_hd95AO  inf_hd95CA  inf_sensitivityC  inf_sensitivityAO  inf_sensitivityCA  inf_specificityC  inf_specificityAO  inf_specificityCA   inf_time
# (func pid=14683) 0  patient0046  0.734069   0.109899        NaN  22.158520  30.635763        NaN   0.738356    0.103263         NaN  44.955532   63.370338         NaN          0.679510           0.056102                NaN          0.994072           0.999984                1.0  12.584039
# (func pid=14683) 1  patient0047  0.606263   0.195773        0.0  18.275667  28.746304        NaN   0.607129    0.197241         0.0  35.749126   46.486557         NaN          0.488281           0.114120                0.0          0.996331           0.999978                1.0  12.548581
# (func pid=14683) 2  patient0048  0.741058   0.047154        0.0  29.732138  36.485615        NaN   0.752269    0.051990         0.0  63.158531   62.056427         NaN          0.711966           0.027938                0.0          0.992922           0.999973                1.0   9.622596
# (func pid=14683) 3  patient0049  0.784688   0.247116        NaN  26.115129  23.409399        NaN   0.784067    0.241765         NaN  50.960770   43.749287         NaN          0.760417           0.146363                NaN          0.993537           0.999944                1.0   6.996651
# (func pid=14683) 4  patient0050  0.760936   0.097754        NaN  39.051247  36.523964        NaN   0.769498    0.115338         NaN  77.897369   69.523735         NaN          0.707798           0.062137                NaN          0.995039           0.999990                1.0   9.331892

# %% [markdown]
# 測試訓練結果

# %%
# testing
# !python ../CardiacSegV2/expers/tune.py \
--tune_mode="test" \
--exp_name={exp_name} \
--data_name={data_name} \
--data_dir={data_dir} \
--root_exp_dir={root_exp_dir} \
--model_name={model_name}\
--model_dir={model_dir} \
--log_dir={log_dir} \
--eval_dir={eval_dir} \
--data_dicts_json={data_dicts_json} \
--pin_memory \
--out_channels=4 \
--patch_size=4 \
--feature_size=24 \
--drop_rate=0.1 \
--depths 2 2 6 2 \
--kernel_size 7 \
--exp_rate 4 \
--norm_name='layer' \
--a_min=-42 \
--a_max=423 \
--space_x=0.7 \
--space_y=0.7 \
--space_z=1.0 \
--roi_x=128 \
--roi_y=128 \
--roi_z=128 \
--optim="AdamW" \
--lr=5e-4 \
--weight_decay=5e-4 \
--checkpoint={final_checkpoint} \
--use_init_weights \
--infer_post_process \
--resume_tuner \
--save_eval_csv \
--test_mode
# Out:
# 2025-10-12 02:33:38,455	INFO worker.py:1625 -- Started a local Ray instance.
# 2025-10-12 02:33:38,576	INFO packaging.py:520 -- Creating a file package for local directory '/root/Document/ai_cup_ctseg/CardiacSegV2'.
# 2025-10-12 02:33:38,614	WARNING packaging.py:394 -- File /root/Document/ai_cup_ctseg/CardiacSegV2/.git/objects/pack/pack-69949eee409e54934508cf24419a0eb87c481e44.pack is very large (17.31MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['/root/Document/ai_cup_ctseg/CardiacSegV2/.git/objects/pack/pack-69949eee409e54934508cf24419a0eb87c481e44.pack']})`
# 2025-10-12 02:33:38,723	INFO packaging.py:347 -- Pushing file package 'gcs://_ray_pkg_428460d57aad73b5.zip' (37.74MiB) to Ray cluster...
# 2025-10-12 02:33:39,071	INFO packaging.py:360 -- Successfully pushed file package 'gcs://_ray_pkg_428460d57aad73b5.zip'.
# test mode
# resume tuner form /root/Document/ai_cup_ctseg/CardiacSegV2/exps/exps/swinunetr/chgh/tune_results
# 2025-10-12 02:33:40,884	INFO experiment_analysis.py:812 -- No `self.trials`. Drawing logdirs from checkpoint file. This may result in some information that is out of sync, as checkpointing is periodic.
# run test mode ...
# cuda is available
# model: swinunetr
# loss: dice ce loss
# optimzer: AdamW
# {'lr': 0.0005, 'weight_decay': 0.0005}
# load json from /root/Document/ai_cup_ctseg/CardiacSegV2/exps/data_dicts/chgh/AICUP_training.json
# train files (40): ['patient0001', 'patient0002', 'patient0003', 'patient0004', 'patient0005', 'patient0006', 'patient0007', 'patient0008', 'patient0009', 'patient0010', 'patient0011', 'patient0012', 'patient0013', 'patient0014', 'patient0015', 'patient0016', 'patient0017', 'patient0018', 'patient0019', 'patient0020', 'patient0021', 'patient0022', 'patient0023', 'patient0024', 'patient0025', 'patient0026', 'patient0027', 'patient0028', 'patient0029', 'patient0030', 'patient0031', 'patient0032', 'patient0033', 'patient0034', 'patient0035', 'patient0036', 'patient0037', 'patient0038', 'patient0039', 'patient0040']
# val files (5): ['patient0041', 'patient0042', 'patient0043', 'patient0044', 'patient0045']
# test files (5): ['patient0046', 'patient0047', 'patient0048', 'patient0049', 'patient0050']
# infer data: {'image': '/root/Document/ai_cup_ctseg/CardiacSegV2/dataset/chgh/patient0046.nii.gz', 'label': '/root/Document/ai_cup_ctseg/CardiacSegV2/dataset/chgh/patient0046_gt.nii.gz'}
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/inferers/utils.py:220: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   win_data = torch.cat([inputs[win_slice] for win_slice in unravel_slice]).to(sw_device)
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:929: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# /root/miniconda3/envs/ctseg/lib/python3.11/site-packages/monai/inferers/utils.py:354: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out[idx_zm] += p
# ^C
